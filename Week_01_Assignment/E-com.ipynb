# %% [markdown]
# ### Objective Of Week 1 Assignment :-

# %% [markdown]
# Learn Python basics and perform basic data exploration and cleaning using Pandas. Steps:
#
# 1- Load a CSV dataset into a Pandas DataFrame.
#
# 2- Explore data (head/tail, shape, columns, data types).
#
# 3- Handle missing values (identify, fill/drop).
#
# 4- Perform basic operations (filter rows, select columns).
#
# 5- Remove duplicates.
#
# 6- Create a derived column (total_amount = price * quantity).
#
# 7- Save the cleaned dataset as a new CSV file.
#
# Output: Jupyter Notebook (.ipynb) + cleaned CSV + brief summary.

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## 1.We are loading the CSV dataset into a Pandas DataFrame for data analysis and preprocessing.

# %%
import pandas as pd
import numpy as np

# %%
ecom_data = pd.read_csv("DataSet/e-commerce-dataset.csv")
ecom_data
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...     3.5             11
# 996  Women White Patterned Dial & White Straps Anal...     5.0             22
# 997  Women Rose Gold-Toned Mirrored Analogue Watch ...     2.8              5
# 998  Men Black Brass Dial & Black Stainless Steel S...     4.3             17
# 999                           Purple Textured Yoga Mat     3.8            161
#
#      initial_price  discount   final_price currency  \
# 0             3995      58.0   "₹3,995.00"      INR
# 1             2899      35.0   "₹2,899.00"      INR
# 2             2999      65.0   "₹2,999.00"      INR
# 3             1675      52.0   "₹1,675.00"      INR
# 4             2899      17.0   "₹2,899.00"      INR
# ..             ...       ...           ...      ...
# 995          11890      50.0  "₹11,890.00"      INR
# 996           8900      45.0   "₹8,900.00"      INR
# 997           7950      50.0   "₹7,950.00"      INR
# 998           3295      20.0   "₹2,636.00"      INR
# 999            699      31.0     "₹699.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/837...  ...
# 1    http://assets.myntassets.com/assets/images/913...  ...
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 3    http://assets.myntassets.com/assets/images/137...  ...
# 4    http://assets.myntassets.com/assets/images/pro...  ...
# ..                                                 ...  ...
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 0    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1    {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2    {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3    {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# ..                                                 ...                 ...
# 995  {"1_star":3,"2_stars":0,"3_stars":2,"4_stars":...                 NaN
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# 997  {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...                 NaN
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...                 NaN
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#         seller_name                                              sizes  \
# 0               NaN                               [{"size":"Onesize"}]
# 1               NaN                               [{"size":"Onesize"}]
# 2               NaN                                     [{"size":"S"}]
# 3               NaN                               [{"size":"Onesize"}]
# 4               NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
# ..              ...                                                ...
# 995             NaN                               [{"size":"Onesize"}]
# 996             NaN                               [{"size":"Onesize"}]
# 997             NaN                               [{"size":"Onesize"}]
# 998  Tru███m R███il                               [{"size":"Onesize"}]
# 999             NaN                                [{"size":"Medium"}]
#
#                                                 videos  \
# 0                                ["rw-8376765_cae700"]
# 1                                ["rw-9136281_cae700"]
# 2    ["https://videos.myntassets.com/assets/videos/...
# 3    ["https://videos.myntassets.com/assets/videos/...
# 4                                                  NaN
# ..                                                 ...
# 995                                    ["pi-13698258"]
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                     seller_information  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                NaN
#
#                                       variations  \
# 0                                           [{}]
# 1                                        [{},{}]
# 2                            [{},{},{},{},{},{}]
# 3                                            NaN
# 4    [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
# ..                                           ...
# 995                                          NaN
# 996                                          NaN
# 997                    [{},{},{},{},{},{},{},{}]
# 998                                          NaN
# 999                                [{},{},{},{}]
#
#                                             best_offer  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category
# 0    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4    [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
# ..                                                 ...        ...
# 995  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 997  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [1000 rows x 24 columns]

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## 2.Now, we are going to explore the dataset by examining its head and tail records, shape, column names, sample, and data types

# %%
ecom_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
# 3  http://assets.myntassets.com/assets/images/137...  ...
# 4  http://assets.myntassets.com/assets/images/pro...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
# [5 rows x 24 columns]

# %%
ecom_data.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
#                                                 images  ...  \
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 995  {"1_star":3,"2_stars":0,"3_stars":2,"4_stars":...                 NaN
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# 997  {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...                 NaN
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...                 NaN
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#         seller_name                 sizes  \
# 995             NaN  [{"size":"Onesize"}]
# 996             NaN  [{"size":"Onesize"}]
# 997             NaN  [{"size":"Onesize"}]
# 998  Tru███m R███il  [{"size":"Onesize"}]
# 999             NaN   [{"size":"Medium"}]
#
#                                                 videos  \
# 995                                    ["pi-13698258"]
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                     seller_information  \
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                NaN
#
#                     variations  \
# 995                        NaN
# 996                        NaN
# 997  [{},{},{},{},{},{},{},{}]
# 998                        NaN
# 999              [{},{},{},{}]
#
#                                             best_offer  \
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category
# 995  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 997  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [5 rows x 24 columns]

# %%
ecom_data.head(1)
# Out:
#    product_id        title             product_description  rating  \
# 0     8376765  Lino Perros  Women Navy Blue Solid Backpack     3.8
#
#    ratings_count  initial_price  discount  final_price currency  \
# 0             15           3995      58.0  "₹3,995.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
#
#   seller_name                 sizes                 videos seller_information  \
# 0         NaN  [{"size":"Onesize"}]  ["rw-8376765_cae700"]                NaN
#
#   variations best_offer                                        more_offers  \
# 0       [{}]         {}  [{"offer_name":"10% Instant Discount on Citi C...
#
#     category
# 0  backpacks
#
# [1 rows x 24 columns]

# %%
ecom_data.tail(1)
# Out:
#      product_id    title       product_description  rating  ratings_count  \
# 999    18601682  BOLDFIT  Purple Textured Yoga Mat     3.8            161
#
#      initial_price  discount final_price currency  \
# 999            699      31.0   "₹699.00"      INR
#
#                                                 images  ...  \
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#     seller_name                sizes videos seller_information     variations  \
# 999         NaN  [{"size":"Medium"}]    NaN                NaN  [{},{},{},{}]
#
#     best_offer                                        more_offers   category
# 999         {}  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [1 rows x 24 columns]

# %%
ecom_data.sample()
# Out:
#      product_id           title             product_description  rating  \
# 201    20195790  Dupatta Bazaar  Sequin Embroidered Net Dupatta     4.7
#
#      ratings_count  initial_price  discount final_price currency  \
# 201             10            999      48.0   "₹999.00"      INR
#
#                                                 images  ...  \
# 201  http://assets.myntassets.com/assets/images/201...  ...
#
#                                        amount_of_stars what_customers_said  \
# 201  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
#
#     seller_name                 sizes videos seller_information  \
# 201         NaN  [{"size":"Onesize"}]    NaN                NaN
#
#                                    variations best_offer  \
# 201  [{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                            more_offers category
# 201  [{"offer_name":"10% Instant Discount on Citi C...  dupatta
#
# [1 rows x 24 columns]

# %%
ecom_data.sample(2)
# Out:
#      product_id           title  \
# 337    22217088      DressBerry
# 641    20042696  Flying Machine
#
#                                 product_description  rating  ratings_count  \
# 337                        Open Back Flatform Heels     4.1             34
# 641  Men White Standard Slim Fit Solid Casual Shirt     3.9            102
#
#      initial_price  discount  final_price currency  \
# 337           1599      54.0    "₹735.00"      INR
# 641           1999      55.0  "₹1,999.00"      INR
#
#                                                 images  ...  \
# 337  http://assets.myntassets.com/assets/images/222...  ...
# 641  http://assets.myntassets.com/assets/images/200...  ...
#
#                                        amount_of_stars  \
# 337  {"1_star":1,"2_stars":2,"3_stars":7,"4_stars":...
# 641  {"1_star":16,"2_stars":5,"3_stars":8,"4_stars"...
#
#                                    what_customers_said         seller_name  \
# 337  [{"percentage":"100","value_name":"Fit, Just R...  KIR███ENT███RIS███
# 641  [{"percentage":"70","value_name":"Fit, Just Ri...                 NaN
#
#                                                  sizes videos  \
# 337  [{"size":"36","value":"23.2cm","value_name":"T...    NaN
# 641  [{"size":"36","value":"36.0in","value_name":"C...    NaN
#
#                                     seller_information variations  \
# 337  LOW███GRO███ FL█████████ERT███████████████████...    [{},{}]
# 641                                                NaN        NaN
#
#                                             best_offer  \
# 337  {"applicable_on":"Orders above Rs. 749 (only o...
# 641                                                 {}
#
#                                            more_offers category
# 337  [{"offer_name":"10% Instant Discount on IndusI...    heels
# 641  [{"offer_name":"10% Instant Discount on Citi C...   shirts
#
# [2 rows x 24 columns]

# %%
ecom_data.shape
# Out:
# (1000, 24)

# %%
ecom_data.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
ecom_data.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
# -----------------

# %% [markdown]
# ## 3.Now, we are going to handle missing values by identifying them and applying appropriate techniques such as filling or dropping the missing data.

# %%
ecom_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
# 3  http://assets.myntassets.com/assets/images/137...  ...
# 4  http://assets.myntassets.com/assets/images/pro...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
# [5 rows x 24 columns]

# %%
ecom_data.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
ecom_data[['discount','what_customers_said',]]
# Out:
#      discount what_customers_said
# 0        58.0                 NaN
# 1        35.0                 NaN
# 2        65.0                 NaN
# 3        52.0                 NaN
# 4        17.0                 NaN
# ..        ...                 ...
# 995      50.0                 NaN
# 996      45.0                 NaN
# 997      50.0                 NaN
# 998      20.0                 NaN
# 999      31.0                 NaN
#
# [1000 rows x 2 columns]

# %%
ecom_data['seller_name'].fillna('Unknown Seller Name',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9760\696256919.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ecom_data['seller_name'].fillna('Unknown Seller Name',inplace=True)

# %%
ecom_data['what_customers_said'].fillna('No reviews from customer',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9760\2702441426.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ecom_data['what_customers_said'].fillna('No reviews from customer',inplace=True)

# %%
ecom_data['videos'].fillna('No Url',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9760\2410088154.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ecom_data['videos'].fillna('No Url',inplace=True)

# %%
ecom_data['variations'].fillna('[]',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9760\870936592.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ecom_data['variations'].fillna('[]',inplace=True)

# %%
ecom_data['seller_information'].fillna('[]',inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9760\3830924156.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ecom_data['seller_information'].fillna('[]',inplace=True)

# %%
ecom_data['discount'].fillna(0,inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9760\1779432581.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ecom_data['discount'].fillna(0,inplace=True)

# %%
ecom_data.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# ## 4.Now, we are going to perform basic data operations such as filtering rows and selecting specific columns from the dataset.

# %%
ecom_data[ecom_data['rating']>3.9]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 992    11791782              CASIO
# 993    19322504                V2A
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ..                                                 ...     ...            ...
# 992  Youth Digital Women Red Digital Watch I117 DW-...     4.6             29
# 993  Girls Blue Printed Dial & Pink Straps Digital ...     4.0              6
# 994         Women Silver-Toned Analogue Watch FCN0001B     4.5            149
# 996  Women White Patterned Dial & White Straps Anal...     5.0             22
# 998  Men Black Brass Dial & Black Stainless Steel S...     4.3             17
#
#      initial_price  discount  final_price currency  \
# 1             2899      35.0  "₹2,899.00"      INR
# 2             2999      65.0  "₹2,999.00"      INR
# 3             1675      52.0  "₹1,675.00"      INR
# 4             2899      17.0  "₹2,899.00"      INR
# 5             1399       0.0  "₹1,399.00"      INR
# ..             ...       ...          ...      ...
# 992           3595      10.0  "₹3,235.00"      INR
# 993           1599      50.0    "₹799.00"      INR
# 994           6250      70.0  "₹6,250.00"      INR
# 996           8900      45.0  "₹8,900.00"      INR
# 998           3295      20.0  "₹2,636.00"      INR
#
#                                                 images  ...  \
# 1    http://assets.myntassets.com/assets/images/913...  ...
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 3    http://assets.myntassets.com/assets/images/137...  ...
# 4    http://assets.myntassets.com/assets/images/pro...  ...
# 5    http://assets.myntassets.com/assets/images/171...  ...
# ..                                                 ...  ...
# 992  http://assets.myntassets.com/assets/images/117...  ...
# 993  http://assets.myntassets.com/assets/images/193...  ...
# 994  http://assets.myntassets.com/assets/images/848...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
#
#                                        amount_of_stars  \
# 1    {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...
# 2    {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...
# 3    {"1_star":33,"2_stars":21,"3_stars":69,"4_star...
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 5    {"1_star":2,"2_stars":2,"3_stars":0,"4_stars":...
# ..                                                 ...
# 992  {"1_star":1,"2_stars":1,"3_stars":0,"4_stars":...
# 993  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 994  {"1_star":7,"2_stars":1,"3_stars":8,"4_stars":...
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...
#
#           what_customers_said  \
# 1    No reviews from customer
# 2    No reviews from customer
# 3    No reviews from customer
# 4    No reviews from customer
# 5    No reviews from customer
# ..                        ...
# 992  No reviews from customer
# 993  No reviews from customer
# 994  No reviews from customer
# 996  No reviews from customer
# 998  No reviews from customer
#
#                                           seller_name  \
# 1                                 Unknown Seller Name
# 2                                 Unknown Seller Name
# 3                                 Unknown Seller Name
# 4                                 Unknown Seller Name
# 5    H &███Hen███ & █████████eta█████████████████████
# ..                                                ...
# 992                                Fla███ech███tai███
# 993                                    Br ███erp███es
# 994                               Unknown Seller Name
# 996                               Unknown Seller Name
# 998                                    Tru███m R███il
#
#                                                  sizes  \
# 1                                 [{"size":"Onesize"}]
# 2                                       [{"size":"S"}]
# 3                                 [{"size":"Onesize"}]
# 4    [{"size":"M","value":"45.0in","value_name":"Fr...
# 5                                 [{"size":"Onesize"}]
# ..                                                 ...
# 992                               [{"size":"Onesize"}]
# 993                               [{"size":"Onesize"}]
# 994                               [{"size":"Onesize"}]
# 996                               [{"size":"Onesize"}]
# 998                               [{"size":"Onesize"}]
#
#                                                 videos  \
# 1                                ["rw-9136281_cae700"]
# 2    ["https://videos.myntassets.com/assets/videos/...
# 3    ["https://videos.myntassets.com/assets/videos/...
# 4                                               No Url
# 5                                               No Url
# ..                                                 ...
# 992  ["https://videos.myntassets.com/assets/videos/...
# 993                                             No Url
# 994  ["rw-8481603_cae700","https://videos.myntasset...
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 998                                             No Url
#
#                                     seller_information  \
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# 5    Pra███yat███fra█████████PVT███████████████████...
# ..                                                 ...
# 992  3rd███165███th █████████, s███████████████████...
# 993      Kha███ no███122█████████lhi██████████████████
# 994                                                 []
# 996                                                 []
# 998  Sho███o. ███-10█████████enu███████████████████...
#
#                                       variations  \
# 1                                        [{},{}]
# 2                            [{},{},{},{},{},{}]
# 3                                             []
# 4    [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
# 5                                        [{},{}]
# ..                                           ...
# 992                                           []
# 993                                           []
# 994                                           []
# 996                                           []
# 998                                           []
#
#                                             best_offer  \
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# 5    {"applicable_on":"Orders above Rs. 1499 (only ...
# ..                                                 ...
# 992  {"applicable_on":"Orders above Rs. 1499 (only ...
# 993  {"applicable_on":"Orders above Rs. 999 (only o...
# 994                                                 {}
# 996                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
#
#                                            more_offers              category
# 1    [{"offer_name":"10% Instant Discount on Citi C...             backpacks
# 2    [{"offer_name":"10% Instant Discount on Citi C...             backpacks
# 3    [{"offer_name":"10% Instant Discount on Citi C...             backpacks
# 4    [{"offer_name":"10% Instant Discount on IndusI...             bath-robe
# 5    [{"offer_name":"10% Instant Discount on IndusI...  bathroom-accessories
# ..                                                 ...                   ...
# 992  [{"offer_name":"10% Instant Discount on IndusI...               watches
# 993  [{"offer_name":"10% Instant Discount on IndusI...               watches
# 994  [{"offer_name":"10% Instant Discount on Citi C...               watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...               watches
# 998  [{"offer_name":"10% Instant Discount on IndusI...               watches
#
# [615 rows x 24 columns]

# %%
ecom_data[(ecom_data['rating']>=4.3) & (ecom_data['ratings_count']>=200)]
# Out:
#      product_id              title  \
# 2      17633752              Lavie
# 3       1376949             F Gear
# 24     15115018             Jockey
# 107    18962984             Athena
# 143    10691426          SASSAFRAS
# 209    10564232  PRITA BY PRIYAASI
# 211    10135431           Priyaasi
# 258    15787112          Mamaearth
# 347    19020502    U.S. Polo Assn.
# 383    18973888              Levis
# 398    18973728              Levis
# 399    18903330              Levis
# 400    18973740              Levis
# 430    18973914              Levis
# 473    13446422               Biba
# 653    13624708               Nike
# 719    18373646             ADIDAS
# 746    11990978           Roadster
# 748    11990952           Roadster
# 773     6510138           Roadster
# 839    17268524                H&M
# 950    13502414               Puma
# 966    12953958        Allen Solly
# 972    16287616            Juniper
# 973    16287462            Juniper
# 975    16293018               Nayo
# 979     9452773     Louis Philippe
# 988     8076639  French Connection
# 991     2466414       Daniel Klein
#
#                                    product_description  rating  ratings_count  \
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 24   Non-Wired Non-Padded Combed Cotton Workout Bra...     4.4           1582
# 107      Burgundy Off-Shoulder Scrunchie Bodycon Dress     4.3            236
# 143        Black & Beige Ikat Print Cotton Shirt Dress     4.5           4441
# 209  Multicoloured Gold-Plated Beaded Handcrafted C...     4.3            727
# 211              Green Gold-Plated Dome Shaped Jhumkas     4.5            347
# 258  Oil-Free Face Moisturizer With Turmeric & Saff...     4.3            903
# 347    Men Red & Navy Blue Colourblocked Puffer Jacket     4.4            338
# 383        Men Skinny Fit Heavy Fade Stretchable Jeans     4.4            333
# 398                 Men 65504 Skinny Tapered Fit Jeans     4.4            260
# 399  Women Blue Skinny Fit High-Rise Stretchable Jeans     4.4            235
# 400  Men Blue 512 Slim Tapered Fit Mid Rise Stretch...     4.3            340
# 430  Men Blue 512 Slim Tapered Fit Mid Rise Light F...     4.4            243
# 473  Women Cream-Coloured Motifs Print Panelled Cot...     4.4            749
# 653  Men Black Solid Standard Fit CHALLENGER DRI FI...     4.4            376
# 719        Men Black Woven Design Immute Running Shoes     4.3            319
# 746  Women Red & Grey Melange Abstract Self Design ...     4.4            302
# 748                  Women Red Ribbed Pullover Sweater     4.3            449
# 773                  Men Black Solid Hooded Sweatshirt     4.3            959
# 839                Women Brown Halter Neck Cropped Top     4.4            203
# 950  Men Navy Blue & White Performance Cat Printed ...     4.3            327
# 966   Men Maroon Solid Polo Collar Pure Cotton T-shirt     4.4            409
# 972           Lime Green Mandarin Collar Printed Tunic     4.3            346
# 973               Yellow Mandarin Collar Printed Tunic     4.3            335
# 975                 Black & White Printed Cotton Kurti     4.3            687
# 979            Men Brown Solid Leather Two Fold Wallet     4.3            401
# 988       Women Charcoal Grey Analogue Watch FC1317RGM     4.4            563
# 991               Women Brown Analogue Watch DK11467-6     4.4            940
#
#      initial_price  discount  final_price currency  \
# 2             2999      65.0  "₹2,999.00"      INR
# 3             1675      52.0  "₹1,675.00"      INR
# 24             579       0.0    "₹579.00"      INR
# 107           2499      68.0    "₹799.00"      INR
# 143           2199      65.0    "₹769.00"      INR
# 209           1130      69.0    "₹350.00"      INR
# 211           1000      50.0    "₹500.00"      INR
# 258            319      12.0    "₹280.00"      INR
# 347           6299      53.0  "₹2,960.00"      INR
# 383           4099       0.0  "₹4,099.00"      INR
# 398           4399      47.0  "₹4,399.00"      INR
# 399           3299      20.0  "₹1,649.00"      INR
# 400           4099      57.0  "₹4,099.00"      INR
# 430           3799      60.0  "₹2,089.00"      INR
# 473           4995      50.0  "₹2,997.00"      INR
# 653           1795       0.0  "₹1,795.00"      INR
# 719           3799      35.0  "₹2,469.00"      INR
# 746           1999      61.0  "₹1,999.00"      INR
# 748           1699      61.0  "₹1,699.00"      INR
# 773           1999      50.0  "₹1,999.00"      INR
# 839            699      25.0    "₹699.00"      INR
# 950           1499       0.0  "₹1,499.00"      INR
# 966            999      40.0    "₹599.00"      INR
# 972           1299      51.0    "₹636.00"      INR
# 973           1299      43.0    "₹740.00"      INR
# 975           1199      43.0    "₹683.00"      INR
# 979           1799      25.0  "₹1,799.00"      INR
# 988           6250      60.0  "₹6,250.00"      INR
# 991           6950      53.0  "₹3,266.00"      INR
#
#                                                 images  ...  \
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 3    http://assets.myntassets.com/assets/images/137...  ...
# 24   http://assets.myntassets.com/assets/images/151...  ...
# 107  http://assets.myntassets.com/assets/images/189...  ...
# 143  http://assets.myntassets.com/assets/images/106...  ...
# 209  http://assets.myntassets.com/assets/images/105...  ...
# 211  http://assets.myntassets.com/assets/images/101...  ...
# 258  http://assets.myntassets.com/assets/images/157...  ...
# 347  http://assets.myntassets.com/assets/images/190...  ...
# 383  http://assets.myntassets.com/assets/images/189...  ...
# 398  http://assets.myntassets.com/assets/images/189...  ...
# 399  http://assets.myntassets.com/assets/images/189...  ...
# 400  http://assets.myntassets.com/assets/images/189...  ...
# 430  http://assets.myntassets.com/assets/images/189...  ...
# 473  http://assets.myntassets.com/assets/images/134...  ...
# 653  http://assets.myntassets.com/assets/images/136...  ...
# 719  http://assets.myntassets.com/assets/images/183...  ...
# 746  http://assets.myntassets.com/assets/images/119...  ...
# 748  http://assets.myntassets.com/assets/images/119...  ...
# 773  http://assets.myntassets.com/assets/images/651...  ...
# 839  http://assets.myntassets.com/assets/images/172...  ...
# 950  http://assets.myntassets.com/assets/images/135...  ...
# 966  http://assets.myntassets.com/assets/images/129...  ...
# 972  http://assets.myntassets.com/assets/images/162...  ...
# 973  http://assets.myntassets.com/assets/images/162...  ...
# 975  http://assets.myntassets.com/assets/images/162...  ...
# 979  http://assets.myntassets.com/assets/images/945...  ...
# 988  http://assets.myntassets.com/assets/images/807...  ...
# 991  http://assets.myntassets.com/assets/images/246...  ...
#
#                                        amount_of_stars  \
# 2    {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...
# 3    {"1_star":33,"2_stars":21,"3_stars":69,"4_star...
# 24   {"1_star":90,"2_stars":25,"3_stars":93,"4_star...
# 107  {"1_star":23,"2_stars":5,"3_stars":15,"4_stars...
# 143  {"1_star":126,"2_stars":78,"3_stars":288,"4_st...
# 209  {"1_star":48,"2_stars":26,"3_stars":62,"4_star...
# 211  {"1_star":12,"2_stars":5,"3_stars":18,"4_stars...
# 258  {"1_star":40,"2_stars":23,"3_stars":77,"4_star...
# 347  {"1_star":17,"2_stars":7,"3_stars":14,"4_stars...
# 383  {"1_star":26,"2_stars":1,"3_stars":11,"4_stars...
# 398  {"1_star":18,"2_stars":6,"3_stars":13,"4_stars...
# 399  {"1_star":13,"2_stars":4,"3_stars":16,"4_stars...
# 400  {"1_star":28,"2_stars":12,"3_stars":14,"4_star...
# 430  {"1_star":15,"2_stars":5,"3_stars":12,"4_stars...
# 473  {"1_star":44,"2_stars":17,"3_stars":56,"4_star...
# 653  {"1_star":22,"2_stars":8,"3_stars":22,"4_stars...
# 719  {"1_star":21,"2_stars":5,"3_stars":25,"4_stars...
# 746  {"1_star":10,"2_stars":12,"3_stars":18,"4_star...
# 748  {"1_star":33,"2_stars":11,"3_stars":33,"4_star...
# 773  {"1_star":49,"2_stars":29,"3_stars":68,"4_star...
# 839  {"1_star":6,"2_stars":8,"3_stars":12,"4_stars"...
# 950  {"1_star":22,"2_stars":11,"3_stars":22,"4_star...
# 966  {"1_star":17,"2_stars":6,"3_stars":26,"4_stars...
# 972  {"1_star":16,"2_stars":14,"3_stars":35,"4_star...
# 973  {"1_star":16,"2_stars":13,"3_stars":29,"4_star...
# 975  {"1_star":32,"2_stars":28,"3_stars":51,"4_star...
# 979  {"1_star":23,"2_stars":5,"3_stars":21,"4_stars...
# 988  {"1_star":35,"2_stars":21,"3_stars":22,"4_star...
# 991  {"1_star":56,"2_stars":21,"3_stars":42,"4_star...
#
#                                    what_customers_said  \
# 2                             No reviews from customer
# 3                             No reviews from customer
# 24                            No reviews from customer
# 107  [{"percentage":"68","value_name":"Fit, Just Ri...
# 143  [{"percentage":"79","value_name":"Fit, Just Ri...
# 209                           No reviews from customer
# 211                           No reviews from customer
# 258                           No reviews from customer
# 347  [{"percentage":"71","value_name":"Fit, Just Ri...
# 383  [{"percentage":"74","value_name":"Fit, Just Ri...
# 398  [{"percentage":"82","value_name":"Fit, Just Ri...
# 399  [{"percentage":"83","value_name":"Fit, Just Ri...
# 400  [{"percentage":"78","value_name":"Fit, Just Ri...
# 430  [{"percentage":"81","value_name":"Fit, Just Ri...
# 473  [{"percentage":"75","value_name":"Fit, Just Ri...
# 653                           No reviews from customer
# 719                           No reviews from customer
# 746  [{"percentage":"82","value_name":"Fit, Just Ri...
# 748  [{"percentage":"66","value_name":"Fit, Just Ri...
# 773  [{"percentage":"84","value_name":"Fit, Just Ri...
# 839                           No reviews from customer
# 950  [{"percentage":"78","value_name":"Fit, Just Ri...
# 966  [{"percentage":"96","value_name":"Fit, Just Ri...
# 972                           No reviews from customer
# 973                           No reviews from customer
# 975                           No reviews from customer
# 979                           No reviews from customer
# 988                           No reviews from customer
# 991                           No reviews from customer
#
#                               seller_name  \
# 2                     Unknown Seller Name
# 3                     Unknown Seller Name
# 24                         Tru███m R███il
# 107                         APE███PPA███S
# 143                    ARD███ Re███l C███
# 209        PRI███DES███S P█████████MIT███
# 211        PRI███DES███S P█████████MIT███
# 258     Hon███ Co███mer█████████Lim██████
# 347     ARV███ LI███TYL█████████LIM██████
# 383                          Vis███ St███
# 398                          Vis███ St███
# 399            Lev███tra███ In█████████td
# 400                          Vis███ St███
# 430            Lev███tra███ In█████████td
# 473                 Fla███tar███mme██████
# 653                   Unknown Seller Name
# 719                 Fla███tar███mme██████
# 746                   Unknown Seller Name
# 748                   Unknown Seller Name
# 773                   Unknown Seller Name
# 839                   Unknown Seller Name
# 950                   Unknown Seller Name
# 966     Wes███ry ███din█████████d_M██████
# 972  AMA███XPO███ IN█████████AL █████████
# 973            AMA███XPO███ IN█████████AL
# 975              Bhu███E R███il █████████
# 979                   Unknown Seller Name
# 988                   Unknown Seller Name
# 991     DES███ER ███GRE█████████IA ██████
#
#                                                  sizes  \
# 2                                       [{"size":"S"}]
# 3                                 [{"size":"Onesize"}]
# 24   [{"size":"S","value":"34.0in","value_name":"Ov...
# 107  [{"size":"XS","value":"8.0in","value_name":"Sl...
# 143  [{"size":"XS","value":"32.0in","value_name":"T...
# 209                               [{"size":"Onesize"}]
# 211                               [{"size":"Onesize"}]
# 258                             [{"size":"75-100 ML"}]
# 347  [{"size":"S","value":"38.0in","value_name":"Ch...
# 383  [{"size":"28","value":"28.0in","value_name":"T...
# 398  [{"size":"28","value":"28.0in","value_name":"T...
# 399  [{"size":"25","value":"25.0in","value_name":"T...
# 400  [{"size":"28","value":"28.0in","value_name":"T...
# 430  [{"size":"28","value":"28.0in","value_name":"T...
# 473  [{"size":"S","value":"33.0in","value_name":"To...
# 653  [{"size":"28","value":"28.0in","value_name":"T...
# 719  [{"size":"6","value":"24.5cm","value_name":"To...
# 746  [{"size":"XS","value":"31.0in","value_name":"B...
# 748  [{"size":"XS","value":"31.0in","value_name":"B...
# 773  [{"size":"S","value":"40.5in","value_name":"Ch...
# 839  [{"size":"XXS","value":"30.0in","value_name":"...
# 950  [{"size":"XS","value":"36.61in","value_name":"...
# 966  [{"size":"S","value":"39.0in","value_name":"Ch...
# 972  [{"size":"XS","value":"32.0in","value_name":"T...
# 973  [{"size":"XS","value":"32.0in","value_name":"T...
# 975  [{"size":"S","value":"36.0in","value_name":"Bu...
# 979                               [{"size":"Onesize"}]
# 988                               [{"size":"Onesize"}]
# 991                               [{"size":"Onesize"}]
#
#                                                 videos  \
# 2    ["https://videos.myntassets.com/assets/videos/...
# 3    ["https://videos.myntassets.com/assets/videos/...
# 24                                              No Url
# 107                                             No Url
# 143                                             No Url
# 209                             ["rw-10564232_cae700"]
# 211                             ["rw-10135431_cae700"]
# 258                                             No Url
# 347                                             No Url
# 383  ["rw-18973888_cae700","https://videos.myntasse...
# 398  ["rw-18973728_cae700","https://videos.myntasse...
# 399  ["rw-18903330_cae700","https://videos.myntasse...
# 400  ["rw-18973740_cae700","https://videos.myntasse...
# 430  ["rw-18973914_cae700","https://videos.myntasse...
# 473                             ["rw-13446422_cae700"]
# 653  ["https://videos.myntassets.com/assets/videos/...
# 719  ["rw-18373646_cae700","https://videos.myntasse...
# 746  ["https://videos.myntassets.com/assets/videos/...
# 748                                             No Url
# 773                              ["rw-6510138_cae700"]
# 839                                             No Url
# 950                             ["rw-13502414_cae700"]
# 966  ["rw-12953958_cae700","https://videos.myntasse...
# 972                                             No Url
# 973                                             No Url
# 975                                             No Url
# 979  ["https://videos.myntassets.com/assets/videos/...
# 988  ["rw-8076639_cae700","https://videos.myntasset...
# 991  ["https://videos.myntassets.com/assets/videos/...
#
#                                     seller_information  \
# 2                                                   []
# 3                                                   []
# 24   Sho███o. ███-10█████████enu███████████████████...
# 107  Plo███o. ███, P█████████2Se███████████████████...
# 143  Khe███ No███76/█████████il ███████████████████...
# 209  PRI███DES███S P█████████MIT███████████████████...
# 211  PRI███DES███S P█████████MIT███████████████████...
# 258  Plo███o 6███4th█████████LM ███████████████████...
# 347  10T███LOO███DU █████████ITY███████████████████...
# 383  3rd███oor███o. █████████Mai███████████████████...
# 398  3rd███oor███o. █████████Mai███████████████████...
# 399  Eco███xpr███ Pv█████████no ███████████████████...
# 400  3rd███oor███o. █████████Mai███████████████████...
# 430  Eco███xpr███ Pv█████████no ███████████████████...
# 473  1st███oor███abi█████████02,███████████████████...
# 653                                                 []
# 719  1st███oor███abi█████████02,███████████████████...
# 746                                                 []
# 748                                                 []
# 773                                                 []
# 839                                                 []
# 950                                                 []
# 966  Gro███ Fl███, N█████████old███████████████████...
# 972  G-9███SIT███RA █████████L A███████████████████...
# 973  G-9███PIP███ICO█████████AL ███████████████████...
# 975   F-███-A,███t, █████████flo███████████████████...
# 979                                                 []
# 988                                                 []
# 991  Fir███Flo███ Pl█████████, I███████████████████...
#
#                              variations  \
# 2                   [{},{},{},{},{},{}]
# 3                                    []
# 24   [{},{},{},{},{},{},{},{},{},{},{}]
# 107                          [{},{},{}]
# 143                                [{}]
# 209                                  []
# 211                                  []
# 258                                  []
# 347                                  []
# 383                                  []
# 398                                  []
# 399                                  []
# 400                                  []
# 430                                  []
# 473                                  []
# 653                                [{}]
# 719                                  []
# 746                       [{},{},{},{}]
# 748                       [{},{},{},{}]
# 773                                  []
# 839                    [{},{},{},{},{}]
# 950                                  []
# 966                                  []
# 972                       [{},{},{},{}]
# 973                       [{},{},{},{}]
# 975                             [{},{}]
# 979                                  []
# 988                                  []
# 991                                  []
#
#                                             best_offer  \
# 2                                                   {}
# 3                                                   {}
# 24   {"applicable_on":"Orders above Rs. 649 (only o...
# 107  {"applicable_on":"Orders above Rs. 999 (only o...
# 143  {"applicable_on":"Orders above Rs. 749 (only o...
# 209  {"applicable_on":"Orders above Rs. 649 (only o...
# 211  {"applicable_on":"Orders above Rs. 649 (only o...
# 258  {"applicable_on":"Orders above Rs. 649 (only o...
# 347  {"applicable_on":"Purchase of 3 or more items ...
# 383  {"applicable_on":"Purchase of 3 or more items"...
# 398  {"applicable_on":"Purchase of 3 or more items"...
# 399  {"applicable_on":"Orders above Rs. 1499 (only ...
# 400  {"applicable_on":"Purchase of 3 or more items"...
# 430  {"applicable_on":"Orders above Rs. 1499 (only ...
# 473  {"applicable_on":"Purchase of 3 or more items ...
# 653                                                 {}
# 719  {"applicable_on":"Purchase of 3 or more items ...
# 746                                                 {}
# 748                                                 {}
# 773                                                 {}
# 839                                                 {}
# 950                                                 {}
# 966  {"applicable_on":"Orders above Rs. 649 (only o...
# 972  {"applicable_on":"Orders above Rs. 649 (only o...
# 973  {"applicable_on":"Orders above Rs. 999 (only o...
# 975  {"applicable_on":"Orders above Rs. 999 (only o...
# 979                                                 {}
# 988                                                 {}
# 991  {"applicable_on":"Orders above Rs. 1499 (only ...
#
#                                            more_offers           category
# 2    [{"offer_name":"10% Instant Discount on Citi C...          backpacks
# 3    [{"offer_name":"10% Instant Discount on Citi C...          backpacks
# 24   [{"offer_name":"10% Instant Discount on IndusI...                bra
# 107  [{"offer_name":"10% Instant Discount on IndusI...            dresses
# 143  [{"offer_name":"10% Instant Discount on IndusI...            dresses
# 209  [{"offer_name":"10% Instant Discount on IndusI...           earrings
# 211  [{"offer_name":"10% Instant Discount on IndusI...           earrings
# 258  [{"offer_name":"10% Instant Discount on IndusI...  face-moisturisers
# 347  [{"offer_name":"10% Instant Discount on IndusI...            jackets
# 383  [{"offer_name":"10% Instant Discount on IndusI...              jeans
# 398  [{"offer_name":"10% Instant Discount on IndusI...              jeans
# 399  [{"offer_name":"10% Instant Discount on IndusI...              jeans
# 400  [{"offer_name":"10% Instant Discount on IndusI...              jeans
# 430  [{"offer_name":"10% Instant Discount on IndusI...              jeans
# 473  [{"offer_name":"10% Instant Discount on IndusI...         kurta-sets
# 653  [{"offer_name":"10% Instant Discount on Citi C...             shorts
# 719  [{"offer_name":"10% Instant Discount on IndusI...       sports-shoes
# 746  [{"offer_name":"10% Instant Discount on Citi C...           sweaters
# 748  [{"offer_name":"10% Instant Discount on Citi C...           sweaters
# 773  [{"offer_name":"10% Instant Discount on Citi C...        sweatshirts
# 839  [{"offer_name":"10% Instant Discount on Citi C...               tops
# 950  [{"offer_name":"10% Instant Discount on Citi C...            tshirts
# 966  [{"offer_name":"10% Instant Discount on IndusI...            tshirts
# 972  [{"offer_name":"10% Instant Discount on IndusI...             tunics
# 973  [{"offer_name":"10% Instant Discount on IndusI...             tunics
# 975  [{"offer_name":"10% Instant Discount on IndusI...             tunics
# 979  [{"offer_name":"10% Instant Discount on Citi C...            wallets
# 988  [{"offer_name":"10% Instant Discount on Citi C...            watches
# 991  [{"offer_name":"10% Instant Discount on IndusI...            watches
#
# [29 rows x 24 columns]

# %%
ecom_data[(ecom_data['rating']>=4.3) & (ecom_data['ratings_count']>=200)].shape
# Out:
# (29, 24)

# %%
ecom_data[ecom_data['discount']>=50]
# Out:
#      product_id              title  \
# 0       8376765        Lino Perros
# 2      17633752              Lavie
# 3       1376949             F Gear
# 6      19851824         AVI Living
# 7      18602872            My Room
# ..          ...                ...
# 991     2466414       Daniel Klein
# 993    19322504                V2A
# 994     8481603  French Connection
# 995    13698258              KREDO
# 997     1708108           GIORDANO
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 6            Grey Solid 500 GSM Pure Cotton Bath Towel     4.0              5
# 7    Yellow & Green Floral 140 TC King Bedsheet wit...     4.7             10
# ..                                                 ...     ...            ...
# 991               Women Brown Analogue Watch DK11467-6     4.4            940
# 993  Girls Blue Printed Dial & Pink Straps Digital ...     4.0              6
# 994         Women Silver-Toned Analogue Watch FCN0001B     4.5            149
# 995  Men FORTE Silver Automatic Skeleton Analogue W...     3.5             11
# 997  Women Rose Gold-Toned Mirrored Analogue Watch ...     2.8              5
#
#      initial_price  discount   final_price currency  \
# 0             3995      58.0   "₹3,995.00"      INR
# 2             2999      65.0   "₹2,999.00"      INR
# 3             1675      52.0   "₹1,675.00"      INR
# 6             1399      65.0   "₹1,399.00"      INR
# 7             2999      54.0   "₹2,999.00"      INR
# ..             ...       ...           ...      ...
# 991           6950      53.0   "₹3,266.00"      INR
# 993           1599      50.0     "₹799.00"      INR
# 994           6250      70.0   "₹6,250.00"      INR
# 995          11890      50.0  "₹11,890.00"      INR
# 997           7950      50.0   "₹7,950.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/837...  ...
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 3    http://assets.myntassets.com/assets/images/137...  ...
# 6    http://assets.myntassets.com/assets/images/198...  ...
# 7    http://assets.myntassets.com/assets/images/186...  ...
# ..                                                 ...  ...
# 991  http://assets.myntassets.com/assets/images/246...  ...
# 993  http://assets.myntassets.com/assets/images/193...  ...
# 994  http://assets.myntassets.com/assets/images/848...  ...
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
#
#                                        amount_of_stars  \
# 0    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 2    {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...
# 3    {"1_star":33,"2_stars":21,"3_stars":69,"4_star...
# 6    {"1_star":0,"2_stars":1,"3_stars":0,"4_stars":...
# 7    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# ..                                                 ...
# 991  {"1_star":56,"2_stars":21,"3_stars":42,"4_star...
# 993  {"1_star":1,"2_stars":0,"3_stars":1,"4_stars":...
# 994  {"1_star":7,"2_stars":1,"3_stars":8,"4_stars":...
# 995  {"1_star":3,"2_stars":0,"3_stars":2,"4_stars":...
# 997  {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...
#
#           what_customers_said                        seller_name  \
# 0    No reviews from customer                Unknown Seller Name
# 2    No reviews from customer                Unknown Seller Name
# 3    No reviews from customer                Unknown Seller Name
# 6    No reviews from customer                Unknown Seller Name
# 7    No reviews from customer                Unknown Seller Name
# ..                        ...                                ...
# 991  No reviews from customer  DES███ER ███GRE█████████IA ██████
# 993  No reviews from customer                     Br ███erp███es
# 994  No reviews from customer                Unknown Seller Name
# 995  No reviews from customer                Unknown Seller Name
# 997  No reviews from customer                Unknown Seller Name
#
#                                                  sizes  \
# 0                                 [{"size":"Onesize"}]
# 2                                       [{"size":"S"}]
# 3                                 [{"size":"Onesize"}]
# 6                                 [{"size":"Onesize"}]
# 7    [{"size":"Single"},{"size":"Double Queen"},{"s...
# ..                                                 ...
# 991                               [{"size":"Onesize"}]
# 993                               [{"size":"Onesize"}]
# 994                               [{"size":"Onesize"}]
# 995                               [{"size":"Onesize"}]
# 997                               [{"size":"Onesize"}]
#
#                                                 videos  \
# 0                                ["rw-8376765_cae700"]
# 2    ["https://videos.myntassets.com/assets/videos/...
# 3    ["https://videos.myntassets.com/assets/videos/...
# 6                                               No Url
# 7                                               No Url
# ..                                                 ...
# 991  ["https://videos.myntassets.com/assets/videos/...
# 993                                             No Url
# 994  ["rw-8481603_cae700","https://videos.myntasset...
# 995                                    ["pi-13698258"]
# 997                                             No Url
#
#                                     seller_information  \
# 0                                                   []
# 2                                                   []
# 3                                                   []
# 6                                                   []
# 7                                                   []
# ..                                                 ...
# 991  Fir███Flo███ Pl█████████, I███████████████████...
# 993      Kha███ no███122█████████lhi██████████████████
# 994                                                 []
# 995                                                 []
# 997                                                 []
#
#                     variations  \
# 0                         [{}]
# 2          [{},{},{},{},{},{}]
# 3                           []
# 6                      [{},{}]
# 7                         [{}]
# ..                         ...
# 991                         []
# 993                         []
# 994                         []
# 995                         []
# 997  [{},{},{},{},{},{},{},{}]
#
#                                             best_offer  \
# 0                                                   {}
# 2                                                   {}
# 3                                                   {}
# 6                                                   {}
# 7                                                   {}
# ..                                                 ...
# 991  {"applicable_on":"Orders above Rs. 1499 (only ...
# 993  {"applicable_on":"Orders above Rs. 999 (only o...
# 994                                                 {}
# 995                                                 {}
# 997                                                 {}
#
#                                            more_offers     category
# 0    [{"offer_name":"10% Instant Discount on Citi C...    backpacks
# 2    [{"offer_name":"10% Instant Discount on Citi C...    backpacks
# 3    [{"offer_name":"10% Instant Discount on Citi C...    backpacks
# 6    [{"offer_name":"10% Instant Discount on Citi C...  bath-towels
# 7    [{"offer_name":"10% Instant Discount on Citi C...    bedsheets
# ..                                                 ...          ...
# 991  [{"offer_name":"10% Instant Discount on IndusI...      watches
# 993  [{"offer_name":"10% Instant Discount on IndusI...      watches
# 994  [{"offer_name":"10% Instant Discount on Citi C...      watches
# 995  [{"offer_name":"10% Instant Discount on Citi C...      watches
# 997  [{"offer_name":"10% Instant Discount on Citi C...      watches
#
# [611 rows x 24 columns]

# %%
ecom_data[['product_id', 'title', 'category', 'rating', 'ratings_count']]
# Out:
#      product_id           title   category  rating  ratings_count
# 0       8376765     Lino Perros  backpacks     3.8             15
# 1       9136281  Tommy Hilfiger  backpacks     4.5             67
# 2      17633752           Lavie  backpacks     4.4            226
# 3       1376949          F Gear  backpacks     4.4           1052
# 4      13939916       MYTRIDENT  bath-robe     4.7             12
# ..          ...             ...        ...     ...            ...
# 995    13698258           KREDO    watches     3.5             11
# 996    16896006           GUESS    watches     5.0             22
# 997     1708108        GIORDANO    watches     2.8              5
# 998    19280114        Fastrack    watches     4.3             17
# 999    18601682         BOLDFIT  yoga-mats     3.8            161
#
# [1000 rows x 5 columns]

# %%
ecom_data[['product_id', 'title', 'seller_name', 'seller_information']]
# Out:
#      product_id           title          seller_name  \
# 0       8376765     Lino Perros  Unknown Seller Name
# 1       9136281  Tommy Hilfiger  Unknown Seller Name
# 2      17633752           Lavie  Unknown Seller Name
# 3       1376949          F Gear  Unknown Seller Name
# 4      13939916       MYTRIDENT  Unknown Seller Name
# ..          ...             ...                  ...
# 995    13698258           KREDO  Unknown Seller Name
# 996    16896006           GUESS  Unknown Seller Name
# 997     1708108        GIORDANO  Unknown Seller Name
# 998    19280114        Fastrack       Tru███m R███il
# 999    18601682         BOLDFIT  Unknown Seller Name
#
#                                     seller_information
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 995                                                 []
# 996                                                 []
# 997                                                 []
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                 []
#
# [1000 rows x 4 columns]

# %%
ecom_data[['product_id', 'title','best_offer', 'more_offers']]
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                             best_offer  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers
# 0    [{"offer_name":"10% Instant Discount on Citi C...
# 1    [{"offer_name":"10% Instant Discount on Citi C...
# 2    [{"offer_name":"10% Instant Discount on Citi C...
# 3    [{"offer_name":"10% Instant Discount on Citi C...
# 4    [{"offer_name":"10% Instant Discount on IndusI...
# ..                                                 ...
# 995  [{"offer_name":"10% Instant Discount on Citi C...
# 996  [{"offer_name":"10% Instant Discount on Citi C...
# 997  [{"offer_name":"10% Instant Discount on Citi C...
# 998  [{"offer_name":"10% Instant Discount on IndusI...
# 999  [{"offer_name":"10% Instant Discount on Citi C...
#
# [1000 rows x 4 columns]

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## 5.Now, we are going to identify and remove duplicate records from the dataset.

# %%
ecom_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### No duplicate data was found in the dataset.

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## 6.Now, we are going to create a derived column, total_amount, by multiplying the price and quantity columns.

# %%
ecom_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
# 3  http://assets.myntassets.com/assets/images/137...  ...
# 4  http://assets.myntassets.com/assets/images/pro...  ...
#
#                                      amount_of_stars  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...
# 3  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#         what_customers_said          seller_name  \
# 0  No reviews from customer  Unknown Seller Name
# 1  No reviews from customer  Unknown Seller Name
# 2  No reviews from customer  Unknown Seller Name
# 3  No reviews from customer  Unknown Seller Name
# 4  No reviews from customer  Unknown Seller Name
#
#                                                sizes  \
# 0                               [{"size":"Onesize"}]
# 1                               [{"size":"Onesize"}]
# 2                                     [{"size":"S"}]
# 3                               [{"size":"Onesize"}]
# 4  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                 []
# 1                              ["rw-9136281_cae700"]                 []
# 2  ["https://videos.myntassets.com/assets/videos/...                 []
# 3  ["https://videos.myntassets.com/assets/videos/...                 []
# 4                                             No Url                 []
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                           []         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
# [5 rows x 24 columns]

# %%
ecom_data['final_price'] = ecom_data['final_price'].str.replace('[₹]','',regex=True)

# %%
ecom_data['final_price'] = ecom_data['final_price'].str.replace('[,]','',regex=True)

# %%
ecom_data['final_price'] = ecom_data['final_price'].str.replace('["]','',regex=True)

# %%
ecom_data['final_price'] = ecom_data['final_price'].astype(float)

# %%
ecom_data['final_price']
# Out:
# 0       3995.0
# 1       2899.0
# 2       2999.0
# 3       1675.0
# 4       2899.0
#         ...
# 995    11890.0
# 996     8900.0
# 997     7950.0
# 998     2636.0
# 999      699.0
# Name: final_price, Length: 1000, dtype: float64

# %%
ecom_data.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price               float64
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %%
ecom_data['total_amount'] = ecom_data['ratings_count'] * ecom_data['final_price']

# %%
ecom_data.sample()
# Out:
#      product_id           title            product_description  rating  \
# 496    17307424  Clora Creation  Women Set of 2 Multi Palazzos     4.0
#
#      ratings_count  initial_price  discount  final_price currency  \
# 496              3           2399      59.0        983.0      INR
#
#                                                 images  ...  \
# 496  http://assets.myntassets.com/assets/images/173...  ...
#
#           what_customers_said     seller_name  \
# 496  No reviews from customer  Clo███Cre███on
#
#                                                  sizes  videos  \
# 496  [{"size":"28","value":"28.0in","value_name":"T...  No Url
#
#                                     seller_information variations  \
# 496  C-1███ Ba███ent█████████Col███████████████████...         []
#
#                                             best_offer  \
# 496  {"applicable_on":"Orders above Rs. 999 (only o...
#
#                                            more_offers  category total_amount
# 496  [{"offer_name":"10% Instant Discount on IndusI...  palazzos       2949.0
#
# [1 rows x 25 columns]

# %%
ecom_data
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...     3.5             11
# 996  Women White Patterned Dial & White Straps Anal...     5.0             22
# 997  Women Rose Gold-Toned Mirrored Analogue Watch ...     2.8              5
# 998  Men Black Brass Dial & Black Stainless Steel S...     4.3             17
# 999                           Purple Textured Yoga Mat     3.8            161
#
#      initial_price  discount  final_price currency  \
# 0             3995      58.0       3995.0      INR
# 1             2899      35.0       2899.0      INR
# 2             2999      65.0       2999.0      INR
# 3             1675      52.0       1675.0      INR
# 4             2899      17.0       2899.0      INR
# ..             ...       ...          ...      ...
# 995          11890      50.0      11890.0      INR
# 996           8900      45.0       8900.0      INR
# 997           7950      50.0       7950.0      INR
# 998           3295      20.0       2636.0      INR
# 999            699      31.0        699.0      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/837...  ...
# 1    http://assets.myntassets.com/assets/images/913...  ...
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 3    http://assets.myntassets.com/assets/images/137...  ...
# 4    http://assets.myntassets.com/assets/images/pro...  ...
# ..                                                 ...  ...
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#           what_customers_said          seller_name  \
# 0    No reviews from customer  Unknown Seller Name
# 1    No reviews from customer  Unknown Seller Name
# 2    No reviews from customer  Unknown Seller Name
# 3    No reviews from customer  Unknown Seller Name
# 4    No reviews from customer  Unknown Seller Name
# ..                        ...                  ...
# 995  No reviews from customer  Unknown Seller Name
# 996  No reviews from customer  Unknown Seller Name
# 997  No reviews from customer  Unknown Seller Name
# 998  No reviews from customer       Tru███m R███il
# 999  No reviews from customer  Unknown Seller Name
#
#                                                  sizes  \
# 0                                 [{"size":"Onesize"}]
# 1                                 [{"size":"Onesize"}]
# 2                                       [{"size":"S"}]
# 3                                 [{"size":"Onesize"}]
# 4    [{"size":"M","value":"45.0in","value_name":"Fr...
# ..                                                 ...
# 995                               [{"size":"Onesize"}]
# 996                               [{"size":"Onesize"}]
# 997                               [{"size":"Onesize"}]
# 998                               [{"size":"Onesize"}]
# 999                                [{"size":"Medium"}]
#
#                                                 videos  \
# 0                                ["rw-8376765_cae700"]
# 1                                ["rw-9136281_cae700"]
# 2    ["https://videos.myntassets.com/assets/videos/...
# 3    ["https://videos.myntassets.com/assets/videos/...
# 4                                               No Url
# ..                                                 ...
# 995                                    ["pi-13698258"]
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 997                                             No Url
# 998                                             No Url
# 999                                             No Url
#
#                                     seller_information  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 995                                                 []
# 996                                                 []
# 997                                                 []
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                 []
#
#                                       variations  \
# 0                                           [{}]
# 1                                        [{},{}]
# 2                            [{},{},{},{},{},{}]
# 3                                             []
# 4    [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
# ..                                           ...
# 995                                           []
# 996                                           []
# 997                    [{},{},{},{},{},{},{},{}]
# 998                                           []
# 999                                [{},{},{},{}]
#
#                                             best_offer  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category total_amount
# 0    [{"offer_name":"10% Instant Discount on Citi C...  backpacks      59925.0
# 1    [{"offer_name":"10% Instant Discount on Citi C...  backpacks     194233.0
# 2    [{"offer_name":"10% Instant Discount on Citi C...  backpacks     677774.0
# 3    [{"offer_name":"10% Instant Discount on Citi C...  backpacks    1762100.0
# 4    [{"offer_name":"10% Instant Discount on IndusI...  bath-robe      34788.0
# ..                                                 ...        ...          ...
# 995  [{"offer_name":"10% Instant Discount on Citi C...    watches     130790.0
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches     195800.0
# 997  [{"offer_name":"10% Instant Discount on Citi C...    watches      39750.0
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches      44812.0
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats     112539.0
#
# [1000 rows x 25 columns]

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# ## 7.Finally, we are going to save the cleaned dataset as a new CSV file for further analysis and future use.

# %%
ecom_data.to_csv('e-commerce-dataset-Final.csv', index=False)
print("CSV file saved successfully.")
# Out:
# CSV file saved successfully.
